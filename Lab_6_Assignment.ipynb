# %% [markdown]
# # Lab 6 Assignment
#
# #### Lab 6 Assignment is due on Tuesday October 22 at 8:00 pm.
#
# #### Complete this notebook, by introducing and executing the required code and answering the related questions.
#
# #### When you have finished your work and wish to submit your assignment, download this notebook as a pdf file File > Save and Export Notebook As > PDF or File > Print > Save as PDF.  Submit the pdf file to Lab 6 Assignment in Crowdmark.
#
# #### You can copy, paste, and modify code from previous labs if you wish, as opposed to writing code from scratch. Open the previous lab and highlight the code you want. Then copy and paste the code into this assignment and make the necessary modifications.
#
# #### If you have questions, please ask.
#
# ---

# %% [markdown]
# ## Reminder - working with notebooks
#
# #### 1) It is important to save your work, exit the notebook, and logout of syzygy whenever you are finished working on the notebook for that session.
#
# - **Select File > Save Notebook or select the Save icon above to save your work.**
# - **To exit the notebook, select File > Close and Shutdown Notebook.**
# - **Select File > Log Out.**
#
#
# #### 2) When you resume your work on a notebook, your previous work/output may still be displayed, but none of your previous work is maintained in memory accessible by the notebook. In particular, you will need to load the dataset again in order to continue working with the data. One easy way to refresh your notebook is to go to the notebook cell where you left off and do the following.
#
# - **Select Kernel > Restart Kernel and Run up to Selected Cell.**
# #### This will run all of the code in your notebook up to the selected cell.

# %% [markdown]
# ## Load Data:

# %%
source("http://www.openintro.org/data/R/law_resume.R")

# %% [markdown]
# The `source` function is used to import the dataset that will be used in the assignment. The data that is available to you is called `law_resume`. This command instructs R to access the OpenIntro website and retrieve some data, which is in a file called `law_resume.R`. The .R indicates a file format, like .csv, .txt etc. R is capable of importing data files of various formats (using the appropriate command). The `law_resume` dataset is already in a format native to R.

# %% [markdown]
# ## Data Information:
#
# ### Data Set:
#
# #### Name: ####
# * `law_resume`
#
#
# #### Variables: ####
#
# The variables included in the dataset are
#
# * `class`: The resume presented irrelevant details suggesting either *high* or *low* social class.
# * `gender`: The resume implied the candidate was either *male* or *female*.
# * `outcome`: If the candidate received an invitation for an *interview* or *not*.

# %% [markdown]
# ## Gender, Socioeconomic Class, and Interview Invites
#
# Do elite law firms discriminate in their hiring decisions based upon factors such as the social class of applicants?
#
# Resumes were sent out to 316 top law firms in the United States. Each law firm represents an observational unit, or subject, in this study. There were two randomized characteristics of each resume. First, the gender associated with the resume was randomized by assigning a first name of either James or Julia. Second, the socioeconomic class of the candidate was randomly assigned and represented through five minor changes associated with personal interests and other other minor details (e.g. an extracurricular activity of sailing team vs track and field). The outcome variable was whether the candidate received an interview.
#
# Tilcsik A, Rivera LA. 2016. Class Advantage, Commitment Penalty. The Gendered Effect of Social Class Signals in an Elite Labor Market. American Sociological Review 81:6 p1097-1131.
#
# ---

# %% [markdown]
# ### Exercise 1: Is this study an experiment, or an observational study? (No explanation required)
# ### (1 mark)

# %% [markdown]
# ### Answer:

# %% [markdown]
# ### Exercise 2: What proportion of all candidates received an interview? Calculate the proportion and state the proportion.
# ### (2 marks)

# %% [markdown]
# ### Answer:

# %% [markdown]
# ### Exercise 3: Construct and display a table that records the counts of candidates in each class group (`class`) that received and did not receive an interview (`outcome`).
# ### (3 marks)

# %% [markdown]
# ### Exercise 4: Construct and display a table that records the proportion, or percentage, of candidates in each class group (`class`) that received and did not receive an interview (`outcome`).
# ### (3 marks)

# %% [markdown]
# ### Exercise 5: What is the difference in the proportion of candidates from high socioeconomic class and low socioeconomic class who received an interview.
# ### (1 mark)

# %% [markdown]
# ### Exercise 6: Construct and display a mosaic plot that displays the relationship between the candidates socioeconomic class (`class`) and whether the candidate received and interview (`outcome`).
# ### (3 marks)

# %% [markdown]
# There are two possible explanations for the difference in the proportion of candidates of high socioeconomic class and candidates of low socioeconomic class who received an interview.
#
# i) Socioeconomic class and interview invitation are independent. They have no relationship. Difference in proportion of candidates of high socioeconomic class and candidates of low socioeconomic class who received an interview is due to chance.
#
# ii) Socioeconomic class and interview invitation are dependent/associated. Difference in proportion of candidates of high socioeconomic class and candidates of low socioeconomic class who received an interview is not due to chance. Law firms discriminate based upon socioeconomic class and candidates from high socioeconomic class have a greater chance of receiving an interview.

# %% [markdown]
# We can simulate the study under the chance model, that is under the assumption that there is no association between the socioeconomic class of the candidate and interview invitation.

# %% [markdown]
# The results of 1000 simulations appear below. The permutation distribution is the chance distribution that we discussed in class. For each simulation we calculated the proportion of candidates in high socioeconomic class  who received an interview, the proportion of candidates in low socioeconomic class who received an interview, and the difference in those proportions. These are the results one would expect as a result of chance, i.e. the chance model.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Exercise 7:  In 1000 simulations, how many produced a difference in the proportions of candidates in high socioeconomic class and low socioeconomic class who received an interview that was at least as big as the difference observed in our study?
# ### (1 mark)

# %% [markdown]
# ### Answer:

# %% [markdown]
# ### Exercise 8: What do the simulation results suggest about the association between the socioeconomic class of the candidate and whether the candidate received an interview? That is, does the data provide sufficiently strong evidence to conclude that law firms discriminate based upon socioeconomic class? Briefly explain your answer.
# ### (3 marks)

# %% [markdown]
# ### Answer:

# %% [markdown]
# - **When you have finished your work and wish to submit your lab, you need to download this notebook as a pdf file. There are two common ways to do this.**
# 1) **File > Save and Export Notebook As > PDF.**
# 2) **File > Print > Save As PDF.**
# - **Submit the pdf file to Lab 4 in Crowdmark.**
#
#
# #### It is important to save your work, exit the notebook, and logout of syzygy when you are done.
#
# - **Select File > Save Notebook or select the Save icon above to save your work.**
# - **To exit the notebook, select File > Close and Shutdown Notebook.**
# - **Select File > Log Out.**
